# %%
import pandas as pd
import numpy as np
from tkinter import ttk
from tkinter import filedialog
from tkinter import *
from tkinter.ttk import *
import os

# %%
# Inputs and Parameters

# File Path
filePath = "C:/Users/marym/OneDrive/Documents/PropellerCalc/propellers/PER3_20x10E.dat"
file = "PER3_20x10E"
fileName = 'C:/Users/marym/OneDrive/Documents/PropellerCalc/propellers/' + file + '.dat'

# Constants
R = 8.3132                       # Gas Constant (J/K-mol)
M = 0.02896                      # Molar Mass of Earth's Air (kg)
g = 9.806                        # Force of Gravity (N)
P0 = 101325                      # Pressure at Sea Level (Pa) - Double Check Units with this value

# Starting Point
propDia = 20.0 * 0.0254          # Prop Diameter (in)
alt = 1289 * 0.3048              # Altitude w/ coversion (m)
alt = 0.0
T = 15 + 273.15 - 6.5 * alt / 1000   # Ambient Temp (K)
Pressure = P0 * np.exp(-M * g *  alt/ (R * T))    # Pressure at Alt (Pa)
Density = Pressure * M / (R * T) # Air Density ()
Density = 1.225

Throttle = 100.0                 # Throttle value (0 to 100)

# ESC
eCurrMax = 120.0                 # Max current of esc (A      -- Double Check these
eRes = 0.004                     # esc Resistance (milliOhms)      values!!

# Battery Cell -- From LiPos
cells = 6.0                      # Num cells
batVolt = 3.7                    # LiPo per-cell Voltage (V)
batRes = 0.0028                  # bat Resistance (milliOhms)

# Motor
kv = 295.0                       # RPM per Volt 
nLCurr = 1.7                     # No Load Current (A)
nLVolt = 8.4                     # No Load Voltage (V)
mRes = 0.015                     # Motor Resistnace (milliOhms)
mWatt = 2000.0                   # Max Watts of Motor (A)


print('propDiameter: '+str(propDia))
print('altitude: '+str(alt))
print('density: '+str(Density))
print('eCurrMax: '+str(eCurrMax))
print('eRes: '+str(eRes))      
print('battRes: '+str(batRes))           
print('battVolt: '+str(batVolt))
print('cells: '+str(cells))
print('kV: '+str(kv))
print('nLCurr: '+str(nLCurr))
#print('nLVolt: '+str(nLVolt))
print('mRes: '+str(mRes))
print('mWatt: '+str(mWatt))
print('Throttle: '+str(Throttle))
# Out:
# propDiameter: 0.508
# altitude: 0.0
# density: 1.225
# eCurrMax: 120.0
# eRes: 0.004
# battRes: 0.0028
# battVolt: 3.7
# cells: 6.0
# kV: 295.0
# nLCurr: 1.7
# mRes: 0.015
# mWatt: 2000.0
# Throttle: 100.0

# %%
""" Pulling Data """

# Set Column Index for Importing Data
header_list = [str(x) for x in range(13)]

# Read file
propData = pd.read_csv(fileName, sep = '\s+', names = header_list)
propData = propData.to_numpy()
df = pd.DataFrame(propData)
df.to_csv(index = False)

# Find All Rows w/ RPM Data
searchString = "RPM"
mask = np.column_stack([df[col].str.contains(r'' + searchString, na = False)
                        for col in df])
RPMdata = pd.DataFrame.dropna(df.loc[mask.any(axis = 1)], axis = 1)

# %%
"""
Create New Table to bin RPM Values into Groups
Remove Characters from PROP RPM
Change to Numeric Values for Analysis
"""

# First Find Column w/ Numbers
RPMs = RPMdata.apply(pd.to_numeric, errors = 'ignore')

# Second Remove All non-int64 Columns
RPMs = RPMs.select_dtypes(include = ['int64'])

# Third Get First RPM Value Index
a = RPMs.columns.values
indexinRPM = RPMs[a[0]].index[0]

# Delete Unnecessary Top Rows
RPMdf = df.iloc[indexinRPM:]

# Get Max RPM and Index
maxRPM = RPMs.max()
indexMaxRPM = RPMs[a[0]].idxmax()

# Get Index of Each RPM Value to Bin Data
RPMindex = RPMs.index

# Clear Columns w/ Mostly NA
RPMdf = pd.DataFrame.dropna(RPMdf, axis = 'columns', thresh = 10)

# Add Index of Last Row of Database ot RPM DF to Bin
lastIndex = RPMdf.iloc[[-1]].index.values[0]
# Get Index of RPMs ot Group by RPM
RPMindex = np.append(RPMindex, lastIndex)
RPMlabel = RPMs[a[0]].to_list()

# Label Columns - Assumes consistantcy in value-to-columns, V in first column
Units = RPMdf[RPMdf[0].str.match('V')]

# First Row of "V"
unitsRow = Units[0].index[0]

# Takes First Row, Sets as Column Headers
RPMdf.columns = RPMdf.loc[unitsRow]

# Removes All Non-Numeric Rows
RPMdf = RPMdf.apply(lambda x: pd.to_numeric(x, errors = 'coerce')).dropna()

# Group Each RPM
RPMdf = RPMdf.groupby(pd.cut(RPMdf.index, RPMindex,
                             right = False, labels = RPMlabel))

# Printing Out Grouped DataFrame
for name, group in RPMdf:
    print(name)
    print(group)
# Out:
# 1000
# 9      V     J      Pe      Ct      Cp    PWR  Torque  Thrust
# 11   0.0  0.00  0.0000  0.0885  0.0330  0.008   0.535   0.451
# 12   0.5  0.02  0.0633  0.0874  0.0332  0.009   0.539   0.446
# 13   0.9  0.05  0.1239  0.0862  0.0335  0.009   0.543   0.439
# 14   1.4  0.07  0.1818  0.0847  0.0336  0.009   0.546   0.432
# 15   1.8  0.10  0.2368  0.0831  0.0338  0.009   0.549   0.424
# 16   2.3  0.12  0.2889  0.0814  0.0339  0.009   0.550   0.415
# 17   2.7  0.14  0.3380  0.0795  0.0340  0.009   0.551   0.405
# 18   3.2  0.17  0.3841  0.0775  0.0340  0.009   0.551   0.395
# 19   3.6  0.19  0.4270  0.0753  0.0339  0.009   0.551   0.384
# 20   4.1  0.22  0.4666  0.0729  0.0339  0.009   0.549   0.372
# 21   4.6  0.24  0.5030  0.0704  0.0337  0.009   0.547   0.359
# 22   5.0  0.26  0.5361  0.0678  0.0335  0.009   0.543   0.345
# 23   5.5  0.29  0.5660  0.0649  0.0331  0.009   0.537   0.331
# 24   5.9  0.31  0.5926  0.0618  0.0326  0.008   0.530   0.315
# 25   6.4  0.34  0.6158  0.0586  0.0320  0.008   0.520   0.298
# 26   6.8  0.36  0.6359  0.0552  0.0313  0.008   0.509   0.281
# 27   7.3  0.39  0.6530  0.0518  0.0305  0.008   0.496   0.264
# 28   7.8  0.41  0.6670  0.0483  0.0296  0.008   0.481   0.246
# 29   8.2  0.43  0.6789  0.0447  0.0285  0.007   0.463   0.228
# 30   8.7  0.46  0.6884  0.0410  0.0273  0.007   0.442   0.209
# 31   9.1  0.48  0.6960  0.0373  0.0258  0.007   0.418   0.190
# 364  115.1  0.55  0.7139  0.0345  0.0267   9.144  52.390  21.260
# 365  120.1  0.58  0.7004  0.0291  0.0239   8.199  46.977  17.925
# 366  125.1  0.60  0.6667  0.0236  0.0213   7.282  41.721  14.546
# 367  130.2  0.62  0.6103  0.0180  0.0184   6.315  36.181  11.103
# 368  135.2  0.65  0.5123  0.0121  0.0153   5.246  30.055   7.456
# 369  140.2  0.67  0.3348  0.0060  0.0121   4.147  23.762   3.715

# %%
""" Notes & Shortened Terms:
        Curr = Current
        Res = Resistance
        Bat = Battery
        Volt = Voltage
        v = Voltage (when put before term)
        p = Power (when put before term)
        Amps = Amperage
        df = Data Frame
        J = Velocity / (PRs * Diameter (m)) - Prop Advance Ratio
"""
# Out:
# ' Notes & Shortened Terms:\n        Curr = Current\n        Res = Resistance\n        Bat = Battery\n        Volt = Voltage\n        v = Voltage (when put before term)\n        p = Power (when put before term)\n        Amps = Amperage\n        df = Data Frame\n        J = Velocity / (PRs * Diameter (m)) - Prop Advance Ratio\n'

# %%
""" First Calculations """

RPMgroups = np.array(list(RPMdf.groups))

# allAmps array w/ Expected Amp Draw at Max Static Thrust at each velocity
allAmps = []

for groups in RPMgroups:
    RPMgroup = RPMdf.get_group(groups)
    PWR = RPMgroup['PWR'].iloc[0] * 745.7  # Converting HP to Watts
    allAmps.append(PWR / (cells * batVolt))
    
velocityArray = [0]
velocityStep = 1.524
    
def RPMfinder(motorAmpGuess, batAmpGuess, Output, velocity):
    
    # Main Calc for Iteration of pMotorOut
    def pMotorOutCalc(motorAmp, batAmp):
    
        vBat = cells * batVolt - cells * batRes * batAmp         # Total Bat Volts w/ Volt Loss
        vTerm = (vBat - eRes * batAmp) * Throttle / 100          # Volt Drop from esc/Throttle Val
        vDropMotor = motorAmp * mRes                             # Volt Drop from Motor
        pMotorIn = vTerm * batAmp                                # Power Motor Uses during Opt
        vEMF = vTerm - vDropMotor                                # Voltage Motor after losses
        pMotorOut = vEMF * (motorAmp - nLCurr)                   # Power Motor Generates (Voltage of Motor * (Amps of Motor - No Load Motor Amps))
        pMotorIn = vTerm * (motorAmp - nLCurr)                   # Power Motor Receives

        return pMotorIn, pMotorOut, vTerm, motorAmp, vBat, batAmp, vEMF
    
    pMotorIn, pMotorOut, vTerm, motorAmp, vBat, batAmp, vEMF = pMotorOutCalc(motorAmpGuess, batAmpGuess)
    
    RPM = vEMF * kv                # Revolutions/Min of Motor
    RPS = RPM / 60                 # Revolutions/s of Motor
    
    
    if (batAmp > batVolt/batRes):
        raise Exception("Batteries can't supply this much current: " + str(batAmp))
    if (batAmpGuess > eCurrMax):
        raise Exception("ESC will be overloaded, chose larger ESC: " + str(Amps))
    if (RPM < 0):
        raise Exception("RPM is negative, something is wrong: " + str(RPM))
    
    
    # Find Closest Data to RPM Values, above and below
    RPMgroups = np.array(list(RPMdf.groups))
    
    if (RPM > RPMgroups.max()):
        raise Exception("RPM max limit has been reached")
    if (RPM < RPMgroups.min()):
        raise Exception('RPM minimum limit reached')
    
    bottomRPM = RPMgroups[RPMgroups < RPM].max()
    topRPM = RPMgroups[RPMgroups > RPM].min()
    
    # Get Bottom/Top RPM Groups
    bottomRPMdata = RPMdf.get_group(bottomRPM).reset_index()
    topRPMdata = RPMdf.get_group(topRPM).reset_index()
    
    velocityMPH = velocity * 2.23694      # Conversion to MPH
    
    # Finding Relevant Indices
    bottomRPMClosestVel = abs(bottomRPMdata['V'] - velocityMPH).idxmin()
    topRPMClosestVel = abs(topRPMdata['V'] - velocityMPH).idxmin()
    
    # Finding Ct
    bottomCt = bottomRPMdata['Ct'].iloc[bottomRPMClosestVel]  # Coefficeient of Thrust
    topCt = topRPMdata['Ct'].iloc[topRPMClosestVel]
    
    # Finding Cp
    bottomCp = bottomRPMdata['Cp'].iloc[bottomRPMClosestVel]
    topCp = topRPMdata['Cp'].iloc[topRPMClosestVel]
    
    # Finding Torque
    bottomTorque = bottomRPMdata['Torque'].iloc[bottomRPMClosestVel]
    topTorque = topRPMdata['Torque'].iloc[topRPMClosestVel]
    
    # Interpolate to get Coefficient of Power/Thrust for Motor RPM
    Cp = bottomCp + (RPM - bottomRPM) * (topCp - bottomCp) / (topRPM - bottomRPM)
    Ct = bottomCt + (RPM - bottomRPM) * (topCt - bottomCt) / (topRPM - bottomRPM)
    torque = bottomTorque + (RPM - bottomRPM) * (topTorque - bottomTorque) / (topRPM - bottomRPM)
    
    # Prop Power/Thrust Calc
    pProp = Density * RPS**3 * propDia**5 * Cp         # Power Prop requires in kg * m^2 / s^3 (W)
    ThrustProp = Density * RPS**2 * propDia**4 * Ct    # Thrust Prop generates in kg*m/2  (N)
    
    if (Output == 1):
        print('Export final parameters here')
        
    return pMotorIn, pMotorOut, pProp, vTerm, motorAmp, vBat, batAmp, ThrustProp, vEMF, RPM, torque

# %%
""" Final Calculations """

InitMotorGuess = nLCurr + 0.01    # Make First Motor Amp Draw Guess
InitBatGuess = nLCurr + 0.01      # No Load Amp Draw for Motor

# Dataframe for Storing Final Results
resultProp = pd.DataFrame(columns = [ "Battery Current (A)", "RPM (rev/min)", "Thrust (N)", "Power (W)", "Efficiency", "Torque (in-lbf)"])
resultProp.columns.name = 'Velocity (m/s)'

powerTolerance = 0.01 # Tolerance of power to Motor to Prop

velocityPosition = 0 # VelocityArray Position
velocity = velocityArray[velocityPosition] # Current Velocity in m/s

pMotorIn, pMotorOut, pProp, vTerm, motorAmp, vBat, batAmp, ThrustProp, vEMF, RPM, Torque = RPMfinder(InitMotorGuess, InitBatGuess, 0, velocity)

while (ThrustProp > 0):
    
    if (velocity != 0):
        velocityArray.append(velocity)
        
    timeRun = 0   # Counts how many times Loop iterates
    
    pMotorIn, pMotorOut, pProp, vTerm, motorAmp, vBat, batAmp, ThrustProp, vEMF, RPM, Torque = RPMfinder(InitMotorGuess, InitBatGuess, 0, velocity)
    
    
    while (abs(pProp - pMotorOut) > powerTolerance):
        pMotorIn,pMotorOut,pProp,vTerm,motorAmp,vBat,batAmp,ThrustProp,vEMF,RPM,Torque = RPMfinder(InitMotorGuess,InitBatGuess,0,velocity)

        print('Motor Power: ' + str(pMotorOut) + ' W')
        print('Thrust Prop: ' + str(ThrustProp) + ' N')
        print('Prop Power: ' + str(pProp) + ' W')
        print('pMotorIn: ' + str(pMotorIn) + ' W')
        print('prop calc done\n')
        
        if (pMotorOut < 0):
            raise Exception("Motor Power Out is negative, something is wrong")
        
        pESCOut = pMotorIn
        vESCin = (cells * batVolt)- (cells * batRes * batAmp)
        vESCout = (cells * batVolt) - (cells * batRes + mRes) * batAmp
        InitMotorGuess = pProp / vEMF + nLCurr
        InitBatGuess = pESCOut / vESCout
        
        timeRun = timeRun + 1
        print("T" + str(timeRun))
    
    # Runs one More Time (Could Keep previous motorAmp/BatAmp values, they are close to new)
    print("EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE")
    pMotorIn,pMotorOut,pProp,vTerm,motorAmp,vBat,batAmp,ThrustProp,vEMF,RPM,Torque = RPMfinder(InitMotorGuess,InitBatGuess,0,velocity)
    
    efficiency = pMotorOut / pMotorIn
    
    resultProp.loc[velocityArray[velocityPosition]] = [motorAmp, RPM, ThrustProp, pProp, efficiency, Torque]
    
    velocityPosition += 1
    velocity += velocityStep
    print("Max Velocity: " + str(velocityPosition) + " mph")
    

thrustLB = resultProp.loc[:, 'Thrust (N)'] * 0.224809
resultProp['Thrust (lbf)'] = thrustLB

# Removing Last Row b/c FN is 0 so results may be Invalid
resultProp.drop(resultProp.tail(1).index, inplace = True)
resultProp
resultProp.to_csv('TwinMotor.csv')
print("done")
# Out:
# Motor Power: 0.22138782000000023 W
# Thrust Prop: 90.66564490023269 N
# Prop Power: 2564.267106955708 W
# pMotorIn: 0.2216443200000002 W
# prop calc done
#
# T1
# Motor Power: 2367.141942231369 W
# Thrust Prop: 77.26180200050226 N
# Prop Power: 2169.1721557685933 W
# pMotorIn: 2571.3336873649105 W
# prop calc done
#
# T2
# Motor Power: 1928.9028779336888 W
# Thrust Prop: 60.63610421468656 N
# Prop Power: 1493.6276399039816 W
# pMotorIn: 2100.5950791335104 W
# prop calc done
#
# T3
# Motor Power: 1527.2314662898314 W
# Thrust Prop: 63.485540469816364 N
# Prop Power: 1604.348100130075 W
# pMotorIn: 1630.6516030208334 W
# prop calc done
#
# T4
# Motor Power: 1645.1958562522834 W
# Thrust Prop: 66.86939666859462 N
# Prop Power: 1739.550936191511 W
# pMotorIn: 1759.2127866210283 W
# prop calc done
#
# T5
# Motor Power: 1727.2163415540326 W
# Thrust Prop: 65.89350782810585 N
# Prop Power: 1700.1494999387323 W
# pMotorIn: 1854.5529624863323 W
# prop calc done
#
# T6
# Motor Power: 1692.0376828119709 W
# Thrust Prop: 65.24573785288221 N
# Prop Power: 1674.1784842980278 W
# pMotorIn: 1815.450552190536 W
# prop calc done
#
# T7
# Motor Power: 1677.6362580001985 W
# Thrust Prop: 65.52438818475498 N
# Prop Power: 1685.3324906391765 W
# pMotorIn: 1798.4815986386297 W
# prop calc done
#
# T8
# Motor Power: 1686.775478950034 W
# Thrust Prop: 65.64032785201353 N
# Prop Power: 1689.9813733700503 W
# pMotorIn: 1808.7216810760356 W
# prop calc done
#
# T9
# Motor Power: 1689.0709142230685 W
# Thrust Prop: 65.56730136316327 N
# Prop Power: 1687.0526532073611 W
# pMotorIn: 1811.4767629349512 W
# prop calc done
#
# T10
# Motor Power: 1686.8231133096972 W
# Thrust Prop: 65.54887511847487 N
# Prop Power: 1686.3139638508674 W
# pMotorIn: 1808.9393361654054 W
# prop calc done
#
# T11
# Motor Power: 1686.5375102585317 W
# Thrust Prop: 65.56682562123984 N
# Prop Power: 1687.033579711884 W
# pMotorIn: 1808.5807130528767 W
# prop calc done
#
# T12
# Motor Power: 1687.0623019710204 W
# Thrust Prop: 65.56913149417316 N
# Prop Power: 1687.126027748025 W
# pMotorIn: 1809.1766392430789 W
# prop calc done
#
# T13
# Motor Power: 1687.0737851758759 W
# Thrust Prop: 65.56493756003051 N
# Prop Power: 1686.9578841394086 W
# pMotorIn: 1809.1972618290404 W
# prop calc done
#
# T14
# Motor Power: 1686.9566778707829 W
# Thrust Prop: 65.56484071811096 N
# Prop Power: 1686.954001616262 W
# pMotorIn: 1809.0635320460833 W
# prop calc done
#
# T15
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 1 mph
# Motor Power: 1686.965665031903 W
# Thrust Prop: 64.37756892744608 N
# Prop Power: 1559.4636974613852 W
# pMotorIn: 1809.0721353929941 W
# prop calc done
#
# T1
# Motor Power: 1567.8367035202698 W
# Thrust Prop: 65.12805022882705 N
# Prop Power: 1588.9437018920873 W
# pMotorIn: 1672.3421654946796 W
# prop calc done
#
# T2
# Motor Power: 1599.9471254732105 W
# Thrust Prop: 66.10855419317558 N
# Prop Power: 1627.7774116067465 W
# pMotorIn: 1707.2565911989648 W
# prop calc done
#
# T3
# Motor Power: 1624.530117392884 W
# Thrust Prop: 65.82328194689867 N
# Prop Power: 1616.4418937282735 W
# pMotorIn: 1735.5674536858673 W
# prop calc done
#
# T4
# Motor Power: 1614.210403329628 W
# Thrust Prop: 65.62667510682815 N
# Prop Power: 1608.647253215768 W
# pMotorIn: 1724.15558698391 W
# prop calc done
#
# T5
# Motor Power: 1609.6476587540792 W
# Thrust Prop: 65.71507996304081 N
# Prop Power: 1612.1503495300021 W
# pMotorIn: 1718.8437508135846 W
# prop calc done
#
# T6
# Motor Power: 1612.558641728938 W
# Thrust Prop: 65.75112370615413 N
# Prop Power: 1613.5794430152475 W
# pMotorIn: 1722.091200906715 W
# prop calc done
#
# T7
# Motor Power: 1613.3001134988654 W
# Thrust Prop: 65.72647908341726 N
# Prop Power: 1612.6022592239833 W
# pMotorIn: 1722.9700251912648 W
# prop calc done
#
# T8
# Motor Power: 1612.5380900227858 W
# Thrust Prop: 65.72081586844442 N
# Prop Power: 1612.37773918698 W
# pMotorIn: 1722.1140773299485 W
# prop calc done
#
# T9
# Motor Power: 1612.4500328428776 W
# Thrust Prop: 65.72719675665923 N
# Prop Power: 1612.6307124734142 W
# pMotorIn: 1722.0044433159183 W
# prop calc done
#
# T10
# Motor Power: 1612.6376297870609 W
# Thrust Prop: 65.72780725272133 N
# Prop Power: 1612.6549166716989 W
# pMotorIn: 1722.2163516017274 W
# prop calc done
#
# T11
# Motor Power: 1612.6372769538004 W
# Thrust Prop: 65.7262504606743 N
# Prop Power: 1612.5931951673306 W
# pMotorIn: 1722.2183249360316 W
# prop calc done
#
# T12
# Motor Power: 1612.5935463686726 W
# Thrust Prop: 65.72628145656682 N
# Prop Power: 1612.5944240401045 W
# pMotorIn: 1722.1686625764848 W
# prop calc done
#
# T13
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 2 mph
# Motor Power: 1612.5985005031932 W
# Thrust Prop: 64.71434487528143 N
# Prop Power: 1524.9086351224594 W
# pMotorIn: 1722.173734811454 W
# prop calc done
#
# T1
# Motor Power: 1530.4322791382242 W
# Thrust Prop: 65.22808663094683 N
# Prop Power: 1544.0656040123215 W
# pMotorIn: 1628.5255231788562 W
# prop calc done
#
# T2
# Motor Power: 1551.3198726261994 W
# Thrust Prop: 65.90033198197253 N
# Prop Power: 1569.265433544793 W
# pMotorIn: 1651.150220577084 W
# prop calc done
#
# T3
# Motor Power: 1567.277243715761 W
# Thrust Prop: 65.71780419424061 N
# Prop Power: 1562.4083740805356 W
# pMotorIn: 1669.4065209532814 W
# prop calc done
#
# T4
# Motor Power: 1561.01771586387 W
# Thrust Prop: 65.58990922397406 N
# Prop Power: 1557.6102905826026 W
# pMotorIn: 1662.5198830345705 W
# prop calc done
#
# T5
# Motor Power: 1558.1872252452051 W
# Thrust Prop: 65.6430669822834 N
# Prop Power: 1559.6038888111243 W
# pMotorIn: 1659.2512753565304 W
# prop calc done
#
# T6
# Motor Power: 1559.8477441064 W
# Thrust Prop: 65.66552240980664 N
# Prop Power: 1560.4463256708718 W
# pMotorIn: 1661.0937622900544 W
# prop calc done
#
# T7
# Motor Power: 1560.2947342416553 W
# Thrust Prop: 65.6515679406813 N
# Prop Power: 1559.9227907512154 W
# pMotorIn: 1661.6176763819637 W
# prop calc done
#
# T8
# Motor Power: 1559.8851938404975 W
# Thrust Prop: 65.64810646514252 N
# Prop Power: 1559.792935294859 W
# pMotorIn: 1661.160329294279 W
# prop calc done
#
# T9
# Motor Power: 1559.8299747499925 W
# Thrust Prop: 65.65151681775397 N
# Prop Power: 1559.9208728722745 W
# pMotorIn: 1661.093253477186 W
# prop calc done
#
# T10
# Motor Power: 1559.92524950981 W
# Thrust Prop: 65.65191977337454 N
# Prop Power: 1559.9359897941663 W
# pMotorIn: 1661.2002098445748 W
# prop calc done
#
# T11
# Motor Power: 1559.9274364433147 W
# Thrust Prop: 65.65113227583998 N
# Prop Power: 1559.9064467926632 W
# pMotorIn: 1661.203777086903 W
# prop calc done
#
# T12
# Motor Power: 1559.9063774589995 W
# Thrust Prop: 65.65112589230269 N
# Prop Power: 1559.906207314845 W
# pMotorIn: 1661.180020570223 W
# prop calc done
#
# T13
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 3 mph
# Motor Power: 1559.9080846963534 W
# Thrust Prop: 63.580516533083056 N
# Prop Power: 1430.9363920820722 W
# pMotorIn: 1661.1817059412624 W
# prop calc done
#
# T1
# Motor Power: 1438.460135031199 W
# Thrust Prop: 64.28141971197834 N
# Prop Power: 1454.3620176019801 W
# pMotorIn: 1523.836912159693 W
# prop calc done
#
# T2
# Motor Power: 1464.4845758829845 W
# Thrust Prop: 65.22056071802493 N
# Prop Power: 1485.9408731210042 W
# pMotorIn: 1551.7381707494342 W
# prop calc done
#
# T3
# Motor Power: 1483.834266524476 W
# Thrust Prop: 65.02733760318196 N
# Prop Power: 1479.425912083613 W
# pMotorIn: 1573.634720303005 W
# prop calc done
#
# T4
# Motor Power: 1477.815640544838 W
# Thrust Prop: 64.87940939286838 N
# Prop Power: 1474.4443895168179 W
# pMotorIn: 1567.0890872732757 W
# prop calc done
#
# T5
# Motor Power: 1474.9291884699287 W
# Thrust Prop: 64.92402827093166 N
# Prop Power: 1475.946374018475 W
# pMotorIn: 1563.800220031831 W
# prop calc done
#
# T6
# Motor Power: 1476.1882798547977 W
# Thrust Prop: 64.94628313162058 N
# Prop Power: 1476.6957125528068 W
# pMotorIn: 1565.1805938763532 W
# prop calc done
#
# T7
# Motor Power: 1476.5933738689675 W
# Thrust Prop: 64.93687090609691 N
# Prop Power: 1476.3787806671457 W
# pMotorIn: 1565.646211793827 W
# prop calc done
#
# T8
# Motor Power: 1476.3446097663443 W
# Thrust Prop: 64.93372787019261 N
# Prop Power: 1476.2729520829016 W
# pMotorIn: 1565.3718478584467 W
# prop calc done
#
# T9
# Motor Power: 1476.2932588877777 W
# Thrust Prop: 64.93559576873989 N
# Prop Power: 1476.335845457894 W
# pMotorIn: 1565.3119492193312 W
# prop calc done
#
# T10
# Motor Power: 1476.3402288805685 W
# Thrust Prop: 64.93599896511363 N
# Prop Power: 1476.3494214583989 W
# pMotorIn: 1565.363999075644 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 4 mph
# Motor Power: 1476.3455725748636 W
# Thrust Prop: 63.03426328056003 N
# Prop Power: 1407.8113310958313 W
# pMotorIn: 1565.370439306051 W
# prop calc done
#
# T1
# Motor Power: 1411.6652501984718 W
# Thrust Prop: 63.41945871571421 N
# Prop Power: 1420.4223276753037 W
# pMotorIn: 1492.7026254942764 W
# prop calc done
#
# T2
# Motor Power: 1425.5459200866344 W
# Thrust Prop: 63.930512841263976 N
# Prop Power: 1437.2076712389187 W
# pMotorIn: 1507.5802584485998 W
# prop calc done
#
# T3
# Motor Power: 1436.0845475327974 W
# Thrust Prop: 63.819190714086794 N
# Prop Power: 1433.5461284079356 W
# pMotorIn: 1519.4511727011622 W
# prop calc done
#
# T4
# Motor Power: 1432.7148435557135 W
# Thrust Prop: 63.73672277695695 N
# Prop Power: 1430.835512878527 W
# pMotorIn: 1515.7903282587456 W
# prop calc done
#
# T5
# Motor Power: 1431.1046610065653 W
# Thrust Prop: 63.763451935535386 N
# Prop Power: 1431.7138915013397 W
# pMotorIn: 1513.964801733056 W
# prop calc done
#
# T6
# Motor Power: 1431.8407620468256 W
# Thrust Prop: 63.77604839526363 N
# Prop Power: 1432.1278967859084 W
# pMotorIn: 1514.770667996658 W
# prop calc done
#
# T7
# Motor Power: 1432.06917724544 W
# Thrust Prop: 63.770219358598 N
# Prop Power: 1431.9363103979892 W
# pMotorIn: 1515.0319713125111 W
# prop calc done
#
# T8
# Motor Power: 1431.9183780238648 W
# Thrust Prop: 63.76843912490096 N
# Prop Power: 1431.8777999941112 W
# pMotorIn: 1514.8659522247115 W
# prop calc done
#
# T9
# Motor Power: 1431.8898033571313 W
# Thrust Prop: 63.76963078746972 N
# Prop Power: 1431.9169659260688 W
# pMotorIn: 1514.8327295742558 W
# prop calc done
#
# T10
# Motor Power: 1431.919195945669 W
# Thrust Prop: 63.76985217523852 N
# Prop Power: 1431.9242422324721 W
# pMotorIn: 1514.865233440892 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 5 mph
# Motor Power: 1431.921906213689 W
# Thrust Prop: 62.17947667271943 N
# Prop Power: 1386.4518166027822 W
# pMotorIn: 1514.8685217305183 W
# prop calc done
#
# T1
# Motor Power: 1388.94398170993 W
# Thrust Prop: 62.43035651927304 N
# Prop Power: 1394.5464587181975 W
# pMotorIn: 1466.7640053275425 W
# prop calc done
#
# T2
# Motor Power: 1397.857121269737 W
# Thrust Prop: 62.763210737392534 N
# Prop Power: 1405.307828211643 W
# pMotorIn: 1476.2988531614906 W
# prop calc done
#
# T3
# Motor Power: 1404.6117776478231 W
# Thrust Prop: 62.69351434232762 N
# Prop Power: 1403.0524468254425 W
# pMotorIn: 1483.8821755631793 W
# prop calc done
#
# T4
# Motor Power: 1402.533518237093 W
# Thrust Prop: 62.641525444341326 N
# Prop Power: 1401.3707904648825 W
# pMotorIn: 1481.6300414210573 W
# prop calc done
#
# T5
# Motor Power: 1401.531739359281 W
# Thrust Prop: 62.657660773296705 N
# Prop Power: 1401.8926462519896 W
# pMotorIn: 1480.4986877518193 W
# prop calc done
#
# T6
# Motor Power: 1401.9695579010572 W
# Thrust Prop: 62.66537014416823 N
# Prop Power: 1402.1420066662804 W
# pMotorIn: 1480.976709899745 W
# prop calc done
#
# T7
# Motor Power: 1402.1081285807932 W
# Thrust Prop: 62.66197466486545 N
# Prop Power: 1402.0321778880234 W
# pMotorIn: 1481.1344932504317 W
# prop calc done
#
# T8
# Motor Power: 1402.021562068756 W
# Thrust Prop: 62.660910644004574 N
# Prop Power: 1401.99776203837 W
# pMotorIn: 1481.03946451164 W
# prop calc done
#
# T9
# Motor Power: 1402.004451291003 W
# Thrust Prop: 62.66158111623007 N
# Prop Power: 1402.0194484927301 W
# pMotorIn: 1481.0197020701432 W
# prop calc done
#
# T10
# Motor Power: 1402.0207548752173 W
# Thrust Prop: 62.66171205568778 N
# Prop Power: 1402.0236837471564 W
# pMotorIn: 1481.0376765439448 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 6 mph
# Motor Power: 1402.022425145134 W
# Thrust Prop: 59.06798245227331 N
# Prop Power: 1321.9780689862166 W
# pMotorIn: 1481.0396731312692 W
# prop calc done
#
# T1
# Motor Power: 1326.1330317606985 W
# Thrust Prop: 59.492067586187076 N
# Prop Power: 1335.4912290435982 W
# pMotorIn: 1396.4837933807983 W
# prop calc done
#
# T2
W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 11 mph
# Motor Power: 1241.1022569634424 W
# Thrust Prop: 46.96747984450485 N
# Prop Power: 1174.8282508335988 W
# pMotorIn: 1301.06385371814 W
# prop calc done
#
# T1
# Motor Power: 1177.7786044202962 W
# Thrust Prop: 47.295028975976656 N
# Prop Power: 1185.0841307508795 W
# pMotorIn: 1231.5877721193995 W
# prop calc done
#
# T2
# Motor Power: 1189.0196146286996 W
# Thrust Prop: 47.73158082306413 N
# Prop Power: 1198.7810022346157 W
# pMotorIn: 1243.4889897981197 W
# prop calc done
#
# T3
# Motor Power: 1198.0230040439317 W
# Thrust Prop: 47.64797765608746 N
# Prop Power: 1196.1554724646207 W
# pMotorIn: 1253.3778544025197 W
# prop calc done
#
# T4
# Motor Power: 1195.6008872174182 W
# Thrust Prop: 47.586775951469164 N
# Prop Power: 1194.234193789723 W
# pMotorIn: 1250.7856703824598 W
# prop calc done
#
# T5
# Motor Power: 1194.392636210548 W
# Thrust Prop: 47.60427568532043 N
# Prop Power: 1194.7834914251973 W
# pMotorIn: 1249.4530692754827 W
# prop calc done
#
# T6
# Motor Power: 1194.8572772168127 W
# Thrust Prop: 47.61242400559419 N
# Prop Power: 1195.0392758255557 W
# pMotorIn: 1249.953253638076 W
# prop calc done
#
# T7
# Motor Power: 1195.0092472104877 W
# Thrust Prop: 47.60910827603014 N
# Prop Power: 1194.9351902240733 W
# pMotorIn: 1250.1217770020223 W
# prop calc done
#
# T8
# Motor Power: 1194.926035539183 W
# Thrust Prop: 47.60809739267038 N
# Prop Power: 1194.9034574823665 W
# pMotorIn: 1250.0318291357382 W
# prop calc done
#
# T9
# Motor Power: 1194.908784551591 W
# Thrust Prop: 47.60868563045515 N
# Prop Power: 1194.9219228933257 W
# pMotorIn: 1250.0125245229306 W
# prop calc done
#
# T10
# Motor Power: 1194.9229385806855 W
# Thrust Prop: 47.60879778631387 N
# Prop Power: 1194.9254435918265 W
# pMotorIn: 1250.0278735620623 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 12 mph
# Motor Power: 1194.9245441052826 W
# Thrust Prop: 44.54399176723452 N
# Prop Power: 1149.9344018886804 W
# pMotorIn: 1250.0297069335438 W
# prop calc done
#
# T1
# Motor Power: 1151.87564740572 W
# Thrust Prop: 44.7866524730098 N
# Prop Power: 1157.2648952703819 W
# pMotorIn: 1202.9646165413076 W
# prop calc done
#
# T2
# Motor Power: 1159.827168501781 W
# Thrust Prop: 45.10678265729487 N
# Prop Power: 1166.9484399208445 W
# pMotorIn: 1211.3884188082477 W
# prop calc done
#
# T3
# Motor Power: 1166.3992348921013 W
# Thrust Prop: 45.03845691562249 N
# Prop Power: 1164.8804516541493 W
# pMotorIn: 1218.5864921979467 W
# prop calc done
#
# T4
# Motor Power: 1164.4958372870449 W
# Thrust Prop: 44.990586240745486 N
# Prop Power: 1163.4319624182435 W
# pMotorIn: 1216.5492036712985 W
# prop calc done
#
# T5
# Motor Power: 1163.5569317483962 W
# Thrust Prop: 45.00615095069844 N
# Prop Power: 1163.9028897832488 W
# pMotorIn: 1215.5165819064694 W
# prop calc done
#
# T6
# Motor Power: 1163.956699877464 W
# Thrust Prop: 45.01285201095321 N
# Prop Power: 1164.1056482722086 W
# pMotorIn: 1215.9468127773291 W
# prop calc done
#
# T7
# Motor Power: 1164.080053752603 W
# Thrust Prop: 45.00966500825831 N
# Prop Power: 1164.0092161944312 W
# pMotorIn: 1216.083284190143 W
# prop calc done
#
# T8
# Motor Power: 1164.002377737102 W
# Thrust Prop: 45.00881346426412 N
# Prop Power: 1163.9834504864507 W
# pMotorIn: 1215.9993693326783 W
# prop calc done
#
# T9
# Motor Power: 1163.9883322273165 W
# Thrust Prop: 45.00942136119839 N
# Prop Power: 1164.0018439999608 W
# pMotorIn: 1215.9836569058634 W
# prop calc done
#
# T10
# Motor Power: 1164.0025733515013 W
# Thrust Prop: 45.00951218283652 N
# Prop Power: 1164.0045920509287 W
# pMotorIn: 1215.9990879999089 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 13 mph
# Motor Power: 1164.003710163256 W
# Thrust Prop: 42.13997094458087 N
# Prop Power: 1122.9343982945059 W
# pMotorIn: 1216.0004025977935 W
# prop calc done
#
# T1
# Motor Power: 1124.6537400168072 W
# Thrust Prop: 42.354911294767454 N
# Prop Power: 1129.6197060508398 W
# pMotorIn: 1173.0963543798919 W
# prop calc done
#
# T2
# Motor Power: 1131.883850272935 W
# Thrust Prop: 42.637809817418535 N
# Prop Power: 1138.4297910097378 W
# pMotorIn: 1180.7488792370195 W
# prop calc done
#
# T3
# Motor Power: 1137.9362863115946 W
# Thrust Prop: 42.576396767504015 N
# Prop Power: 1136.5161862193827 W
# pMotorIn: 1187.3598040005047 W
# prop calc done
#
# T4
# Motor Power: 1136.1747248865756 W
# Thrust Prop: 42.533885574173944 N
# Prop Power: 1135.191901505338 W
# pMotorIn: 1185.4767598882886 W
# prop calc done
#
# T5
# Motor Power: 1135.3053667187016 W
# Thrust Prop: 42.54802086441452 N
# Prop Power: 1135.6322046502607 W
# pMotorIn: 1184.5233882167097 W
# prop calc done
#
# T6
# Motor Power: 1135.6800336304916 W
# Thrust Prop: 42.55397852594431 N
# Prop Power: 1135.817790494145 W
# pMotorIn: 1184.9259830794658 W
# prop calc done
#
# T7
# Motor Power: 1135.794359601327 W
# Thrust Prop: 42.55106021806359 N
# Prop Power: 1135.72688221233 W
# pMotorIn: 1185.0520821032444 W
# prop calc done
#
# T8
# Motor Power: 1135.7208411729248 W
# Thrust Prop: 42.55030778586467 N
# Prop Power: 1135.7034433945928 W
# pMotorIn: 1184.9727965903219 W
# prop calc done
#
# T9
# Motor Power: 1135.7079430908589 W
# Thrust Prop: 42.55086824623435 N
# Prop Power: 1135.7209021398808 W
# pMotorIn: 1184.9584116205758 W
# prop calc done
#
# T10
# Motor Power: 1135.7215296272195 W
# Thrust Prop: 42.55094640251311 N
# Prop Power: 1135.7233367683225 W
# pMotorIn: 1184.973105685526 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 14 mph
# Motor Power: 1135.7225194324833 W
# Thrust Prop: 39.45772206724877 N
# Prop Power: 1082.599880124606 W
# pMotorIn: 1184.9742499367019 W
# prop calc done
#
# T1
# Motor Power: 1084.7315240929652 W
# Thrust Prop: 39.763984126811316 N
# Prop Power: 1091.8823263501245 W
# pMotorIn: 1129.5477675731054 W
# prop calc done
#
# T2
# Motor Power: 1094.6632588353807 W
# Thrust Prop: 40.16313577372887 N
# Prop Power: 1104.0009691574005 W
# pMotorIn: 1140.0632217340021 W
# prop calc done
#
# T3
# Motor Power: 1103.3049059109683 W
# Thrust Prop: 40.06383952455387 N
# Prop Power: 1100.9840402289014 W
# pMotorIn: 1149.4708310226288 W
# prop calc done
#
# T4
# Motor Power: 1100.5282293948912 W
# Thrust Prop: 39.998763267981275 N
# Prop Power: 1099.0076090521993 W
# pMotorIn: 1146.503057832889 W
# prop calc done
#
# T5
# Motor Power: 1099.1856487300513 W
# Thrust Prop: 40.02420928837848 N
# Prop Power: 1099.7803558819435 W
# pMotorIn: 1145.035434641957 W
# prop calc done
#
# T6
# Motor Power: 1099.847947489854 W
# Thrust Prop: 40.033867147455474 N
# Prop Power: 1100.0736715292476 W
# pMotorIn: 1145.7466087298965 W
# prop calc done
#
# T7
# Motor Power: 1100.033068609144 W
# Thrust Prop: 40.02806659434965 N
# Prop Power: 1099.8975031980506 W
# pMotorIn: 1145.9502863959426 W
# prop calc done
#
# T8
# Motor Power: 1099.8889349107212 W
# Thrust Prop: 40.02684244137085 N
# Prop Power: 1099.8603251381487 W
# pMotorIn: 1145.795007140047 W
# prop calc done
#
# T9
# Motor Power: 1099.8688727013325 W
# Thrust Prop: 40.02806366522446 N
# Prop Power: 1099.897414238977 W
# pMotorIn: 1145.7725929227622 W
# prop calc done
#
# T10
# Motor Power: 1099.8981491899383 W
# Thrust Prop: 40.02816866891926 N
# Prop Power: 1099.9006032572292 W
# pMotorIn: 1145.8042157913674 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 15 mph
# Motor Power: 1099.8989139676062 W
# Thrust Prop: 34.04199087827452 N
# Prop Power: 992.0424004936588 W
# pMotorIn: 1145.805182318868 W
# prop calc done
#
# T1
# Motor Power: 995.9795206492685 W
# Thrust Prop: 34.5540662570745 N
# Prop Power: 1008.9431456471551 W
# pMotorIn: 1033.446908636106 W
# prop calc done
#
# T2
# Motor Power: 1014.1636727493567 W
# Thrust Prop: 35.230006217288356 N
# Prop Power: 1031.0797031105665 W
# pMotorIn: 1052.5962353046261 W
# prop calc done
#
# T3
# Motor Power: 1029.9234655128546 W
# Thrust Prop: 35.08276515352993 N
# Prop Power: 1026.3554294037854 W
# pMotorIn: 1069.627290062368 W
# prop calc done
#
# T4
# Motor Power: 1025.5783326475657 W
# Thrust Prop: 34.983574584970796 N
# Prop Power: 1023.1588262467704 W
# pMotorIn: 1065.0119912819212 W
# prop calc done
#
# T5
# Motor Power: 1023.4106479456793 W
# Thrust Prop: 35.01584848421007 N
# Prop Power: 1024.2095723746957 W
# pMotorIn: 1062.6614918420353 W
# prop calc done
#
# T6
# Motor Power: 1024.312693778073 W
# Thrust Prop: 35.029014743955024 N
# Prop Power: 1024.6317241858658 W
# pMotorIn: 1063.6238415534337 W
# prop calc done
#
# T7
# Motor Power: 1024.5814558413072 W
# Thrust Prop: 35.02259822079273 N
# Prop Power: 1024.425986632654 W
# pMotorIn: 1063.9166949596363 W
# prop calc done
#
# T8
# Motor Power: 1024.4137606673287 W
# Thrust Prop: 35.021037509583536 N
# Prop Power: 1024.3759454676328 W
# pMotorIn: 1063.7372581468571 W
# prop calc done
#
# T9
# Motor Power: 1024.385052218478 W
# Thrust Prop: 35.0222000747179 N
# Prop Power: 1024.413220815954 W
# pMotorIn: 1063.7056939780248 W
# prop calc done
#
# T10
# Motor Power: 1024.4144001195566 W
# Thrust Prop: 35.022350621938074 N
# Prop Power: 1024.4180478307374 W
# pMotorIn: 1063.737169080327 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 16 mph
# Motor Power: 1024.416486581168 W
# Thrust Prop: 31.757978038411217 N
# Prop Power: 958.0842622939422 W
# pMotorIn: 1063.739531009159 W
# prop calc done
#
# T1
# Motor Power: 960.3876228296355 W
# Thrust Prop: 32.06111645999873 N
# Prop Power: 967.9635678339355 W
# pMotorIn: 994.8608720140115 W
# prop calc done
#
# T2
# Motor Power: 971.0076891535647 W
# Thrust Prop: 32.46135262138858 N
# Prop Power: 981.0329366576993 W
# pMotorIn: 1006.0174141689096 W
# prop calc done
#
# T3
# Motor Power: 980.3907416187101 W
# Thrust Prop: 32.37752301000164 N
# Prop Power: 978.2931449250408 W
# pMotorIn: 1016.1144935866957 W
# prop calc done
#
# T4
# Motor Power: 977.858453136246 W
# Thrust Prop: 32.32073587854225 N
# Prop Power: 976.437902665624 W
# pMotorIn: 1013.4321139756574 W
# prop calc done
#
# T5
# Motor Power: 976.5784517816588 W
# Thrust Prop: 32.33911674797656 N
# Prop Power: 977.0383437999784 W
# pMotorIn: 1012.050601077613 W
# prop calc done
#
# T6
# Motor Power: 977.0956400843801 W
# Thrust Prop: 32.346608252597974 N
# Prop Power: 977.2830836227076 W
# pMotorIn: 1012.6006323415337 W
# prop calc done
#
# T7
# Motor Power: 977.2555493582498 W
# Thrust Prop: 32.34300869457399 N
# Prop Power: 977.1654884589938 W
# pMotorIn: 1012.7739313758121 W
# prop calc done
#
# T8
# Motor Power: 977.1587148925413 W
# Thrust Prop: 32.34212314229127 N
# Prop Power: 977.1365584158652 W
# pMotorIn: 1012.6706630426685 W
# prop calc done
#
# T9
# Motor Power: 977.1415608734031 W
# Thrust Prop: 32.342777159375395 N
# Prop Power: 977.1579244386919 W
# pMotorIn: 1012.6519262636305 W
# prop calc done
#
# T10
# Motor Power: 977.1585723927318 W
# Thrust Prop: 32.34286187152975 N
# Prop Power: 977.1606918977999 W
# pMotorIn: 1012.6701067137108 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 17 mph
# Motor Power: 977.1598338818712 W
# Thrust Prop: 29.052795703087146 N
# Prop Power: 906.1674614091387 W
# pMotorIn: 1012.671519610932 W
# prop calc done
#
# T1
# Motor Power: 908.4777436792959 W
# Thrust Prop: 29.36527823622393 N
# Prop Power: 916.5673295328447 W
# pMotorIn: 939.0990429376194 W
# prop calc done
#
# T2
# Motor Power: 919.6191906229384 W
# Thrust Prop: 29.77752112459337 N
# Prop Power: 930.3176650040581 W
# pMotorIn: 950.778097904138 W
# prop calc done
#
# T3
# Motor Power: 929.6685835912291 W
# Thrust Prop: 29.69055960076912 N
# Prop Power: 927.414210935575 W
# pMotorIn: 961.5432626660408 W
# prop calc done
#
# T4
# Motor Power: 926.9804683238232 W
# Thrust Prop: 29.632394263150186 N
# Prop Power: 925.4730497280966 W
# pMotorIn: 958.7035392858395 W
# prop calc done
#
# T5
# Motor Power: 925.6150579931269 W
# Thrust Prop: 29.65146103635877 N
# Prop Power: 926.1092929738041 W
# pMotorIn: 957.2369082742075 W
# prop calc done
#
# T6
# Motor Power: 926.165937769335 W
# Thrust Prop: 29.65906449974139 N
# Prop Power: 926.3630350496313 W
# pMotorIn: 957.820952211136 W
# prop calc done
#
# T7
# Motor Power: 926.3352776402078 W
# Thrust Prop: 29.655339250236633 N
# Prop Power: 926.2387149096387 W
# pMotorIn: 958.0035217428081 W
# prop calc done
#
# T8
# Motor Power: 926.2321274062149 W
# Thrust Prop: 29.65445510852245 N
# Prop Power: 926.2092094794923 W
# pMotorIn: 957.8938894381608 W
# prop calc done
#
# T9
# Motor Power: 926.2142329781061 W
# Thrust Prop: 29.65512935256564 N
# Prop Power: 926.2317102252059 W
# pMotorIn: 957.8744566600895 W
# prop calc done
#
# T10
# Motor Power: 926.2323164305391 W
# Thrust Prop: 29.65521071534574 N
# Prop Power: 926.2344254548458 W
# pMotorIn: 957.8937132508879 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 18 mph
# Motor Power: 926.2335683573738 W
# Thrust Prop: 26.24970671987706 N
# Prop Power: 850.1810069936382 W
# pMotorIn: 957.8951067447196 W
# prop calc done
#
# T1
# Motor Power: 852.4804711411508 W
# Thrust Prop: 26.57003329835188 N
# Prop Power: 861.0449172226154 W
# pMotorIn: 879.2427236442675 W
# prop calc done
#
# T2
# Motor Power: 864.0838027331239 W
# Thrust Prop: 26.99264194697212 N
# Prop Power: 875.4127756945227 W
# pMotorIn: 891.3757783488982 W
# prop calc done
#
# T3
# Motor Power: 874.7679438566187 W
# Thrust Prop: 26.903799558155438 N
# Prop Power: 872.389014587642 W
# pMotorIn: 902.766096367074 W
# prop calc done
#
# T4
# Motor Power: 871.9624659288727 W
# Thrust Prop: 26.844967095494887 N
# Prop Power: 870.3876087187111 W
# pMotorIn: 899.8114733784961 W
# prop calc done
#
# T5
# Motor Power: 870.5273488750194 W
# Thrust Prop: 26.86426743646977 N
# Prop Power: 871.0440971575994 W
# pMotorIn: 898.2777928001366 W
# prop calc done
#
# T6
# Motor Power: 871.0989269112682 W
# Thrust Prop: 26.871838055575644 N
# Prop Power: 871.3016293931024 W
# pMotorIn: 898.8816874414468 W
# prop calc done
#
# T7
# Motor Power: 871.2746157665354 W
# Thrust Prop: 26.8681088580059 N
# Prop Power: 871.1747704644013 W
# pMotorIn: 899.070057318385 W
# prop calc done
#
# T8
# Motor Power: 871.1685230673854 W
# Thrust Prop: 26.86724635755621 N
# Prop Power: 871.1454305752989 W
# pMotorIn: 898.9577177644755 W
# prop calc done
#
# T9
# Motor Power: 871.150259555214 W
# Thrust Prop: 26.867913051017013 N
# Prop Power: 871.1681096355936 W
# pMotorIn: 898.9380095523685 W
# prop calc done
#
# T10
# Motor Power: 871.1686644703414 W
# Thrust Prop: 26.867989651078606 N
# Prop Power: 871.1707153633118 W
# pMotorIn: 898.9575311850363 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 19 mph
# Motor Power: 871.1699023789744 W
# Thrust Prop: 20.140592410119368 N
# Prop Power: 703.2357766144121 W
# pMotorIn: 898.9588974007854 W
# prop calc done
#
# T1
# Motor Power: 707.3924512053204 W
# Thrust Prop: 20.91202715521157 N
# Prop Power: 728.6399113926941 W
# pMotorIn: 725.667842033756 W
# prop calc done
#
# T2
# Motor Power: 734.173888316895 W
# Thrust Prop: 21.929829075110852 N
# Prop Power: 762.3720683327297 W
# pMotorIn: 753.5367422785039 W
# prop calc done
#
# T3
# Motor Power: 760.9653661332842 W
# Thrust Prop: 21.678510419809285 N
# Prop Power: 754.0203481842964 W
# pMotorIn: 781.8084764484531 W
# prop calc done
#
# T4
# Motor Power: 753.1566964752536 W
# Thrust Prop: 21.523497933295218 N
# Prop Power: 748.8763525173556 W
# pMotorIn: 773.6294922583593 W
# prop calc done
#
# T5
# Motor Power: 749.2191096848157 W
# Thrust Prop: 21.585304519619392 N
# Prop Power: 750.926695874365 W
# pMotorIn: 769.4650669955246 W
# prop calc done
#
# T6
# Motor Power: 751.0436959968202 W
# Thrust Prop: 21.606373862541655 N
# Prop Power: 751.6258440443788 W
# pMotorIn: 771.3799546894123 W
# prop calc done
#
# T7
# Motor Power: 751.5515245897554 W
# Thrust Prop: 21.59299964821238 N
# Prop Power: 751.1820328621604 W
# pMotorIn: 771.9186098097863 W
# prop calc done
#
# T8
# Motor Power: 751.1691357381278 W
# Thrust Prop: 21.590678004613814 N
# Prop Power: 751.104995466772 W
# pMotorIn: 771.5166505964672 W
# prop calc done
#
# T9
# Motor Power: 751.1197138572828 W
# Thrust Prop: 21.59332773498302 N
# Prop Power: 751.1929196258912 W
# pMotorIn: 771.4638323852075 W
# prop calc done
#
# T10
# Motor Power: 751.1936302841847 W
# Thrust Prop: 21.59345566528754 N
# Prop Power: 751.197164689554 W
# pMotorIn: 771.5416251220579 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 20 mph
# Motor Power: 751.194448930145 W
# Thrust Prop: 17.925812839533442 N
# Prop Power: 651.6929535564353 W
# pMotorIn: 771.5426309270588 W
# prop calc done
#
# T1
# Motor Power: 653.925596240861 W
# Thrust Prop: 18.36998084952127 N
# Prop Power: 666.6220496782372 W
# pMotorIn: 669.3457046754011 W
# prop calc done
#
# T2
# Motor Power: 669.5494113719143 W
# Thrust Prop: 18.948347024128246 N
# Prop Power: 686.139765821123 W
# pMotorIn: 685.5583594613121 W
# prop calc done
#
# T3
# Motor Power: 685.3921649849443 W
# Thrust Prop: 18.803465438930203 N
# Prop Power: 681.2423210850636 W
# pMotorIn: 702.1836837679688 W
# prop calc done
#
# T4
# Motor Power: 680.7913288028448 W
# Thrust Prop: 18.71577512895572 N
# Prop Power: 678.2807823230472 W
# pMotorIn: 697.3851336113677 W
# prop calc done
#
# T5
# Motor Power: 678.4639968258259 W
# Thrust Prop: 18.75150887107327 N
# Prop Power: 679.4873644333709 W
# pMotorIn: 694.9386792457049 W
# prop calc done
#
# T6
# Motor Power: 679.5477727681667 W
# Thrust Prop: 18.763279684724825 N
# Prop Power: 679.8848897892223 W
# pMotorIn: 696.0709478581194 W
# prop calc done
#
# T7
# Motor Power: 679.8452191331046 W
# Thrust Prop: 18.755553154608375 N
# Prop Power: 679.6239443818824 W
# pMotorIn: 696.3843828159512 W
# prop calc done
#
# T8
# Motor Power: 679.6175089939512 W
# Thrust Prop: 18.754299479983263 N
# Prop Power: 679.5816059390424 W
# pMotorIn: 696.1461767009777 W
# prop calc done
#
# T9
# Motor Power: 679.5894423112835 W
# Thrust Prop: 18.755826165254106 N
# Prop Power: 679.6331644089639 W
# pMotorIn: 696.1164072858568 W
# prop calc done
#
# T10
# Motor Power: 679.6334479498247 W
# Thrust Prop: 18.755881402287322 N
# Prop Power: 679.6350298585276 W
# pMotorIn: 696.1624864692161 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 21 mph
# Motor Power: 679.6335912734165 W
# Thrust Prop: 14.891468522494149 N
# Prop Power: 571.7825908017419 W
# pMotorIn: 696.1627048181141 W
# prop calc done
#
# T1
# Motor Power: 573.8791307399644 W
# Thrust Prop: 15.357327138301692 N
# Prop Power: 587.8468246335378 W
# pMotorIn: 585.6886364336358 W
# prop calc done
#
# T2
# Motor Power: 590.5987183199461 W
# Thrust Prop: 15.962495360369612 N
# Prop Power: 608.8131276446867 W
# pMotorIn: 602.9727787274727 W
# prop calc done
#
# T3
# Motor Power: 608.0865793345712 W
# Thrust Prop: 15.80661823675939 N
# Prop Power: 603.4021738564596 W
# pMotorIn: 621.213050228932 W
# prop calc done
#
# T4
# Motor Power: 602.9739692089665 W
# Thrust Prop: 15.714323896790283 N
# Prop Power: 600.2017971134824 W
# pMotorIn: 615.9045821085989 W
# prop calc done
#
# T5
# Motor Power: 600.3823180779863 W
# Thrust Prop: 15.753386545916396 N
# Prop Power: 601.5560121999126 W
# pMotorIn: 613.1976358730967 W
# prop calc done
#
# T6
# Motor Power: 601.613004010303 W
# Thrust Prop: 15.765702820371649 N
# Prop Power: 601.9830850354588 W
# pMotorIn: 614.4770582983901 W
# prop calc done
#
# T7
# Motor Power: 601.9434981655714 W
# Thrust Prop: 15.757152712692907 N
# Prop Power: 601.686601040082 W
# pMotorIn: 614.8229374104602 W
# prop calc done
#
# T8
# Motor Power: 601.6807825794021 W
# Thrust Prop: 15.755895640256508 N
# Prop Power: 601.6430125788253 W
# pMotorIn: 614.5495404553541 W
# prop calc done
#
# T9
# Motor Power: 601.6509022822349 W
# Thrust Prop: 15.757600319165142 N
# Prop Power: 601.7021217219338 W
# pMotorIn: 614.5180901004926 W
# prop calc done
#
# T10
# Motor Power: 601.7022701772191 W
# Thrust Prop: 15.757632392941625 N
# Prop Power: 601.7032338772424 W
# pMotorIn: 614.571587126859 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 22 mph
# Motor Power: 601.7017777290899 W
# Thrust Prop: 10.993876729308994 N
# Prop Power: 461.7028994772283 W
# pMotorIn: 614.571134740274 W
# prop calc done
#
# T1
# Motor Power: 463.87096079770316 W
# Thrust Prop: 11.454643632686313 N
# Prop Power: 478.7552042042054 W
# pMotorIn: 471.5778854784677 W
# prop calc done
#
# T2
# Motor Power: 481.6676270087103 W
# Thrust Prop: 12.065123806165388 N
# Prop Power: 501.4863548463724 W
# pMotorIn: 489.8586339067159 W
# prop calc done
#
# T3
# Motor Power: 500.8525538772096 W
# Thrust Prop: 11.936510975070583 N
# Prop Power: 496.68452598447533 W
# pMotorIn: 509.70686801097276 W
# prop calc done
#
# T4
# Motor Power: 496.2951116779122 W
# Thrust Prop: 11.85709517253056 N
# Prop Power: 493.722929254419 W
# pMotorIn: 505.0076072778085 W
# prop calc done
#
# T5
# Motor Power: 493.8542627802364 W
# Thrust Prop: 11.883995418583103 N
# Prop Power: 494.72580656058284 W
# pMotorIn: 502.47974156169266 W
# prop calc done
#
# T6
# Motor Power: 494.77156123577754 W
# Thrust Prop: 11.893356087057589 N
# Prop Power: 495.0748556105123 W
# pMotorIn: 503.4264676124369 W
# prop calc done
#
# T7
# Motor Power: 495.05069923533654 W
# Thrust Prop: 11.888416754460051 N
# Prop Power: 494.8906687703808 W
# pMotorIn: 503.71585710954537 W
# prop calc done
#
# T8
# Motor Power: 494.88610277451966 W
# Thrust Prop: 11.887482917811358 N
# Prop Power: 494.8558473095188 W
# pMotorIn: 503.54585052195057 W
# prop calc done
#
# T9
# Motor Power: 494.8599134063328 W
# Thrust Prop: 11.888314564657614 N
# Prop Power: 494.88685823804735 W
# pMotorIn: 503.51863849186054 W
# prop calc done
#
# T10
# Motor Power: 494.88715514452315 W
# Thrust Prop: 11.888375289103777 N
# Prop Power: 494.88912257760364 W
# pMotorIn: 503.5467909791519 W
# prop calc done
#
# T11
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 23 mph
# Motor Power: 494.8884830836674 W
# Thrust Prop: 4.89780158760336 N
# Prop Power: 303.8163197614282 W
# pMotorIn: 503.54818542037515 W
# prop calc done
#
# T1
# Motor Power: 305.7286741035804 W
# Thrust Prop: 5.6261836059446475 N
# Prop Power: 328.9123516262491 W
# pMotorIn: 309.1325536958753 W
# prop calc done
#
# T2
# Motor Power: 331.5515465109434 W
# Thrust Prop: 6.585636502795709 N
# Prop Power: 362.28238887901495 W
# pMotorIn: 335.46161833869377 W
# prop calc done
#
# T3
# Motor Power: 361.5708382860135 W
# Thrust Prop: 6.34626633919665 N
# Prop Power: 353.92436538558553 W
# pMotorIn: 366.19977539742825 W
# prop calc done
#
# T4
# Motor Power: 353.52099272378047 W
# Thrust Prop: 6.2084288783161625 N
# Prop Power: 349.1213131793049 W
# pMotorIn: 357.96505038483093 W
# prop calc done
#
# T5
# Thrust Prop: 3.6082478849362936 N
# Prop Power: 271.99934912564544 W
# pMotorIn: 269.94314088171177 W
# prop calc done
#
# T3
# Motor Power: 271.92149284549953 W
# Thrust Prop: 3.5901178291998113 N
# Prop Power: 271.3206339267622 W
# pMotorIn: 274.5896080278337 W
# prop calc done
#
# T4
# Motor Power: 271.26979267593777 W
# Thrust Prop: 3.578262707902263 N
# Prop Power: 270.8769281614126 W
# pMotorIn: 273.92683310173294 W
# prop calc done
#
# T5
# Motor Power: 270.88716739148043 W
# Thrust Prop: 3.580653091396864 N
# Prop Power: 270.9663874141128 W
# pMotorIn: 273.53697776690314 W
# prop calc done
#
# T6
# Motor Power: 270.97047011316374 W
# Thrust Prop: 3.581606025079951 N
# Prop Power: 271.00205152908944 W
# pMotorIn: 273.6217375631445 W
# prop calc done
#
# T7
# Motor Power: 271.00085808016513 W
# Thrust Prop: 3.5813274918540525 N
# Prop Power: 270.99162720226894 W
# pMotorIn: 273.6527065018736 W
# prop calc done
#
# T8
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 26 mph
# Motor Power: 270.9913212835127 W
# Thrust Prop: 1.7906280466289748 N
# Prop Power: 213.10127638313227 W
# pMotorIn: 273.64299988668733 W
# prop calc done
#
# T1
# Motor Power: 213.49338236565217 W
# Thrust Prop: 1.8490110961231478 N
# Prop Power: 215.4778126625803 W
# pMotorIn: 215.18658009024165 W
# prop calc done
#
# T2
# Motor Power: 216.01640465567525 W
# Thrust Prop: 1.9290982577950337 N
# Prop Power: 218.74036256865702 W
# pMotorIn: 217.73887892087777 W
# prop calc done
#
# T3
# Motor Power: 218.70529439488288 W
# Thrust Prop: 1.9239267077651474 N
# Prop Power: 218.5295980243264 W
# pMotorIn: 220.46825981134467 W
# prop calc done
#
# T4
# Motor Power: 218.5045877524155 W
# Thrust Prop: 1.9202372910677814 N
# Prop Power: 218.3792447437807 W
# pMotorIn: 220.2649269480141 W
# prop calc done
#
# T5
# Motor Power: 218.38165887742366 W
# Thrust Prop: 1.9205935518513504 N
# Prop Power: 218.39376302101797 W
# pMotorIn: 220.14012548369215 W
# prop calc done
#
# T6
# Motor Power: 218.39489014769777 W
# Thrust Prop: 1.9207598809351494 N
# Prop Power: 218.40054125469456 W
# pMotorIn: 220.1535375412681 W
# prop calc done
#
# T7
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 27 mph
# Motor Power: 218.40039240778788 W
# Thrust Prop: 0.0 N
# Prop Power: 171.63904613230258 W
# pMotorIn: 220.159124208932 W
# prop calc done
#
# T1
# Motor Power: 171.8919807922455 W
# Thrust Prop: 0.0 N
# Prop Power: 172.3502582100571 W
# pMotorIn: 173.02117573122814 W
# prop calc done
#
# T2
# Motor Power: 172.7012860536666 W
# Thrust Prop: 0.0 N
# Prop Power: 173.33765334350284 W
# pMotorIn: 173.83597373570566 W
# prop calc done
#
# T3
# Motor Power: 173.3321520086439 W
# Thrust Prop: 0.0 N
# Prop Power: 173.32220896916675 W
# pMotorIn: 174.4744732713635 W
# prop calc done
#
# T4
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# Max Velocity: 28 mph
# done

# %%
print("Done")
